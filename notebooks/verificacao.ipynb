# %%
import pandas as pd

# %%
df = pd.read_csv("../data_normalizada/custo_producao.csv")

df
# Out:
#                                 empreendimento   ano  mes  ano_mes  \
# 0     AGRICULTURA EMPRESARIAL                   2018    1   201801
# 1     AGRICULTURA EMPRESARIAL                   2018    3   201803
# 2     AGRICULTURA EMPRESARIAL                   2018    3   201803
# 3     AGRICULTURA EMPRESARIAL                   2018    5   201805
# 4     AGRICULTURA EMPRESARIAL                   2018    7   201807
# ...                                        ...   ...  ...      ...
# 1383  SOCIOBIODIVERSIDADE                       2024    8   202408
# 1384  SOCIOBIODIVERSIDADE                       2024    8   202408
# 1385  SOCIOBIODIVERSIDADE                       2024    8   202408
# 1386  SOCIOBIODIVERSIDADE                       2024    8   202408
# 1387  SOCIOBIODIVERSIDADE                       2024    8   202408
#
#                                        produto  id_produto  \
# 0     FEIJAO COMUM CORES                              8778
# ...

# %%
df.columns
# Out:
# Index(['empreendimento', 'ano', 'mes', 'ano_mes', 'produto', 'id_produto',
#        'safra', 'uf', 'municipio', 'cod_ibge', 'unidade_comercializacao',
#        'vlr_custo_variavel_ha', 'vlr_custo_variavel_unidade',
#        'vlr_custo_fixo_ha', 'vlr_custo_fixo_unidade', 'vlr_renda_fator_ha',
#        'vlr_renda_fator_unidade'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1388 entries, 0 to 1387
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   empreendimento              1388 non-null   object
#  1   ano                         1388 non-null   int64
#  2   mes                         1388 non-null   int64
#  3   ano_mes                     1388 non-null   int64
#  4   produto                     1388 non-null   object
#  5   id_produto                  1388 non-null   int64
#  6   safra                       1388 non-null   object
#  7   uf                          1388 non-null   object
#  8   municipio                   1388 non-null   object
#  9   cod_ibge                    1388 non-null   int64
#  10  unidade_comercializacao     1388 non-null   object
#  11  vlr_custo_variavel_ha       1388 non-null   float64
#  12  vlr_custo_variavel_unidade  1388 non-null   float64
# ...

# %%
df['produto'].describe()
# Out:
# count                                         1388
# unique                                          48
# top       MILHO
# freq                                           243
# Name: produto, dtype: object
