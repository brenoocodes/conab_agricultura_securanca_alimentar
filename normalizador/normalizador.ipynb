# %% [markdown]
# Normalizar os dados de data no formato csv do pandas

# %%
import pandas as pd
import re
from pathlib import Path

input_dir=Path("../data")
output_dir=Path("../data_normalizada")
output_dir.mkdir(exist_ok=True)

def normalize_name(name):
    name=name.replace(".csv","")
    name=re.sub("(.)([A-Z][a-z]+)",r"\1_\2",name)
    name=re.sub("([a-z0-9])([A-Z])",r"\1_\2",name)
    name=name.replace("-","_").replace(" ","_")
    name=re.sub("_+","_",name)
    return name.lower().strip("_")

for file in input_dir.glob("*.csv"):
    df=pd.read_csv(file,sep=";",decimal=",")
    normalized_name=normalize_name(file.name)
    output_path=output_dir/f"{normalized_name}.csv"
    df.to_csv(output_path,index=False)
# Out:
# C:\Users\breno\AppData\Local\Temp\ipykernel_260\1953045658.py:18: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(file,sep=";",decimal=",")
